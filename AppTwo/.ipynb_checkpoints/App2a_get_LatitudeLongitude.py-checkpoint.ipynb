# %%
import pandas

df1 = pandas.DataFrame([[2,4,6],[10,20,30]])

df1


df1 = pandas.DataFrame([[2,4,6],[10,20,30]],columns=["Price","Age","Value"])

df1

df1 = pandas.DataFrame([[2,4,6],[10,20,30]],columns=["Price","Age","Value"],index=['First',"Second"])

# 

df1

df2 = pandas.DataFrame([{"Name":"John"},{"Name":"Jack"}])

df2


df2 = pandas.DataFrame([{"Name":"John","Surname":"John1"},{"Name":"Jack"}])

df2





df1

type(df1)

type(df2)



dir(df1)

df1.mean()

df1.mean().mean()

type(df1.mean())

# 

df1.Price


df1

type(df1.Price)



























df1.Price.mean()

df1.Price

df1.Price.max()

df1.Price.min()

import pandas

df = pandas.read_csv("supermarkets.csv")

df

from bs4 import BeautifulSoup

import requests

print(1)

r = requests.get("https://en.wikipedia.org/wiki/Eagle")

print(r.content)

soup = BeautifulSoup(r.content)

print(soup.prettyfy)

import os


os.listdir()

import pandas

df1 = pandas.read_csv("supermarkets.csv")

df1 = pandas.read_csv("supermarkets.csv",header=None)

df1 = pandas.read_csv("supermarkets.csv",header=2)

df1 = pandas.read_csv("supermarkets.csv")

df1.set_index("ID")

df2 = pandas.read_json("supermarkets.json")

df2.set_index("ID")

df3 = pandas.read_excel("supermarkets.xlsx")

df3 = pandas.read_excel("supermarkets.xlsx",sheet_name=1)

df3 = pandas.read_excel("supermarkets.xlsx",sheet_name=0)

df4 = pandas.read_csv("supermarkets-commas.txt")

df4 = pandas.read_csv("supermarkets-commas.txt")

df5 = pandas.read_csv("supermarkets-semi-colons.txt",sep=";")

df5.set_index("ID")

df6 = pandas.read_csv("https://pythonhow.com/supermarkets.csv")

df7 = pandas.read_json("https://pythonhow.com/supermarkets.json")

df7.set_index("Address")

df7.set_index("City")

df7 = df7.set_index("Address")
df7.set_index

df7.loc()

df7.loc['735 Dolores St']

df7.loc["735 Dolores St":"332 Hill St","Country":"ID"]
df7.loc["332 Hill St","ID"]
df7.loc["332 Hill St","Country"]
df7.loc[:,"Country"]
list(df7.loc[:,"Country"])
df7.iloc[:,]

df7.iloc[1:3,1:3]

df7.iloc[1:3,1:4]

df7.iloc[:,1:3]

df7.iloc[:,1:4]

df7.iloc[3,1:4]

df7.ix[3,"Name"]

df7.ix[3,4]

df7.drop("City",1)

df8 = df7.drop("332 Hill St",0)

df8.index[0:3]

df8.drop(df8.index[0:3],0)

df8.drop(df8.columns[0:3],1)

df8.index

df8.columns

df8["Continent"] = df8.shape[0]*["North America"]

len(df8.index)

df8.shape

df8.shape[0]


df8.shape[0]*["North America"]

df8

df8["Continent"] = df8.shape[0]*["North America"]

df8

df8["Continent"] = df8["Country"] + " , " + "North America"

df8

df8 = df8_t.T

df8

df8_t["My Address"]=["My City","My Country",10,7,"My Shop","My State","My Continent"]

df8_t

df8 = df8_t.T

df8

df8

from geopy.geocoders import GoogleV3
nom = GoogleV3(scheme = "http")
import geopy

from geopy.geocoders import GoogleV3
nom = GoogleV3(scheme = "http")

dir(geopy)

from geopy.geocoders import Nominatim

nom = Nominatim()

nom.geocode("3666 21st St,San Francisco, CA 94114")

df8

nom.geocode("735 Dolores St,San Francisco,CA 94119")

n = nom.geocode("735 Dolores St,San Francisco,CA 94119")

print(n)

n.latitude

n.longitude

type(n)

nom.geocode("793 Tran Xuan Soan St,Ho Chi Minh,VN")

nom.geocode()

import pandas
df = pandas.read_csv("supermarkets.csv")
df

nom.geocode("6793 Tran Xuan Soan Ho Chi Minh  Vietnam")

df['Address'] = df["Address"] +" , " +df["City"] +" , "+ df["State"]+" , " + df["Country"]

df

nom.geocode(df["Address"])

df

df["Coordinates"] = df["Address"].apply(nom.geocode)

df

df["Address"]

df.index[1:3][1:2]

df.iloc[1,1]

df

nom.geocode(df.iloc[1,1])

df["Coordinates"] = df["Address"].apply(nom.geocode)

df


df["Coordinates"]

df.Coordinates[0].latitude

df["Latitude"] = df["Coordinates"].apply(lambda x: x.latitude)
df["Longitude"] = df["Coordinates"].apply(lambda y: y.longitude)

df["Coordinates"]

df["Latitude"] = df["Coordinates"].apply(lambda x: x.latitude if x != None else None)
df["Longitude"] = df["Coordinates"].apply(lambda y: y.longitude if y != None else None)

df

df["City"] = ["USA","None","USA","USA","USA","USA"]


df

df['6']

df
